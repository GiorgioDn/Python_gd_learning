# %%
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = fetch_california_housing()

X = pd.DataFrame(df.data, columns=df.feature_names)
y = pd.Series(df.target, name="MedHouseVal")
housing = pd.concat([X, y], axis=1)

# %%
housing = housing.drop(columns= ['AveRooms', 'AveBedrms', 'AveOccup', 'MedInc'])

# %%
#remove outlier
for col in housing.columns:
    Q1 = housing[col].quantile(0.3)
    Q3 = housing[col].quantile(0.7)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    housing[col] = np.where(housing[col].between(lower, upper), housing[col], np.nan)

housing = housing.dropna()

# %%
def generate_comprehensive_features(df_input, cols_to_combine):
    df_eng = df_input.copy()
    math_cols = [c for c in cols_to_combine if c not in ['Latitude', 'Longitude', 'Geo_Cluster']]
    
    print(f"   -> Generating combinations on {len(math_cols)} base columns...")

    # A. LOG TRANSFORMATIONS
    for col in math_cols:
        if df_eng[col].min() >= 0:
            df_eng[f'LOG_{col}'] = np.log1p(df_eng[col])

    # B. MULTIPLICATIONS
    for col1, col2 in itertools.combinations(math_cols, 2):
        col_name = f'MULT_{col1}_x_{col2}'
        df_eng[col_name] = df_eng[col1] * df_eng[col2]

    # C. DIVISIONS / RATIOS
    for col1, col2 in itertools.permutations(math_cols, 2):
        col_name = f'RATIO_{col1}_div_{col2}'
        df_eng[col_name] = df_eng[col1] / (df_eng[col2] + 1e-5)

    return df_eng

# %%
cols_for_math = [c for c in X.columns if c != 'Geo_Cluster']
X_full= generate_comprehensive_features(X, cols_for_math)

# Cleaning of inf/nan values generated by divisions
X_full.replace([np.inf, -np.inf], np.nan, inplace=True)
X_full.fillna(0, inplace=True)

housing = pd.concat([X_full, y], axis=1)
housing.info()
# Out:
#    -> Generating combinations on 6 base columns...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 60 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   MedInc                          20640 non-null  float64
#  1   HouseAge                        20640 non-null  float64
#  2   AveRooms                        20640 non-null  float64
#  3   AveBedrms                       20640 non-null  float64
#  4   Population                      20640 non-null  float64
#  5   AveOccup                        20640 non-null  float64
#  6   Latitude                        20640 non-null  float64
#  7   Longitude                       20640 non-null  float64
#  8   LOG_MedInc                      20640 non-null  float64
#  9   LOG_HouseAge                    20640 non-null  float64
#  10  LOG_AveRooms                    20640 non-null  float64
#  11  LOG_AveBedrms                   20640 non-null  float64
#  12  LOG_Population                  20640 non-null  float64
#  13  LOG_AveOccup                    20640 non-null  float64
#  14  MULT_MedInc_x_HouseAge          20640 non-null  float64
#  15  MULT_MedInc_x_AveRooms          20640 non-null  float64
#  16  MULT_MedInc_x_AveBedrms         20640 non-null  float64
#  17  MULT_MedInc_x_Population        20640 non-null  float64
#  18  MULT_MedInc_x_AveOccup          20640 non-null  float64
#  19  MULT_HouseAge_x_AveRooms        20640 non-null  float64
#  20  MULT_HouseAge_x_AveBedrms       20640 non-null  float64
#  21  MULT_HouseAge_x_Population      20640 non-null  float64
#  22  MULT_HouseAge_x_AveOccup        20640 non-null  float64
#  23  MULT_AveRooms_x_AveBedrms       20640 non-null  float64
#  24  MULT_AveRooms_x_Population      20640 non-null  float64
#  25  MULT_AveRooms_x_AveOccup        20640 non-null  float64
#  26  MULT_AveBedrms_x_Population     20640 non-null  float64
#  27  MULT_AveBedrms_x_AveOccup       20640 non-null  float64
#  28  MULT_Population_x_AveOccup      20640 non-null  float64
#  29  RATIO_MedInc_div_HouseAge       20640 non-null  float64
#  30  RATIO_MedInc_div_AveRooms       20640 non-null  float64
#  31  RATIO_MedInc_div_AveBedrms      20640 non-null  float64
#  32  RATIO_MedInc_div_Population     20640 non-null  float64
#  33  RATIO_MedInc_div_AveOccup       20640 non-null  float64
#  34  RATIO_HouseAge_div_MedInc       20640 non-null  float64
#  35  RATIO_HouseAge_div_AveRooms     20640 non-null  float64
#  36  RATIO_HouseAge_div_AveBedrms    20640 non-null  float64
#  37  RATIO_HouseAge_div_Population   20640 non-null  float64
#  38  RATIO_HouseAge_div_AveOccup     20640 non-null  float64
#  39  RATIO_AveRooms_div_MedInc       20640 non-null  float64
#  40  RATIO_AveRooms_div_HouseAge     20640 non-null  float64
#  41  RATIO_AveRooms_div_AveBedrms    20640 non-null  float64
#  42  RATIO_AveRooms_div_Population   20640 non-null  float64
#  43  RATIO_AveRooms_div_AveOccup     20640 non-null  float64
#  44  RATIO_AveBedrms_div_MedInc      20640 non-null  float64
#  45  RATIO_AveBedrms_div_HouseAge    20640 non-null  float64
#  46  RATIO_AveBedrms_div_AveRooms    20640 non-null  float64
#  47  RATIO_AveBedrms_div_Population  20640 non-null  float64
#  48  RATIO_AveBedrms_div_AveOccup    20640 non-null  float64
#  49  RATIO_Population_div_MedInc     20640 non-null  float64
#  50  RATIO_Population_div_HouseAge   20640 non-null  float64
#  51  RATIO_Population_div_AveRooms   20640 non-null  float64
#  52  RATIO_Population_div_AveBedrms  20640 non-null  float64
#  53  RATIO_Population_div_AveOccup   20640 non-null  float64
#  54  RATIO_AveOccup_div_MedInc       20640 non-null  float64
#  55  RATIO_AveOccup_div_HouseAge     20640 non-null  float64
#  56  RATIO_AveOccup_div_AveRooms     20640 non-null  float64
#  57  RATIO_AveOccup_div_AveBedrms    20640 non-null  float64
#  58  RATIO_AveOccup_div_Population   20640 non-null  float64
#  59  MedHouseVal                     20640 non-null  float64
# dtypes: float64(60)
# memory usage: 9.4 MB

# %%
# --- 1. DATA PREPARATION ---
# Load the dataset
X = housing.drop('MedHouseVal', axis=1)
y = housing['MedHouseVal']

# Train/Test split (crucial to evaluate overfitting)
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

# !!! CRUCIAL STEP !!!
# Unlike Decision Trees, Neural Networks require scaled inputs.
# If you don’t do this, gradients may explode or training will be extremely slow.
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

print(f"Input shape: {X_train.shape[1]} features")  # Should be 8

# --- 2. MODEL BUILDING (Architecture Design) ---
model_reg = models.Sequential([
    # Input layer is implicit in the first Dense definition
    # "Funnel" structure: start wide and narrow down
    layers.Dense(128, activation="relu", input_shape=X_train.shape[1:]),
    
    # Second hidden layer to capture complex non-linearities
    layers.Dense(128, activation="relu"),
    
    layers.Dense(64, activation="relu"),
    
    # OUTPUT LAYER (Regression)
    # 1 neuron (price)
    # No activation (can output any value)
    layers.Dense(1)
])

# --- 3. COMPILATION (The brain) ---
model_reg.compile(
    loss="mse",         # Mean Squared Error: standard for regression
    optimizer="adam",   # Adam handles learning rate adaptively
    metrics=["mae"]     # Monitor absolute error (more interpretable than MSE)
)

# --- 4. TRAINING (The work) ---
history = model_reg.fit(
    X_train, y_train,
    epochs=50,                  # 50 full passes
    batch_size=32,              # update weights every 32 samples
    validation_data=(X_valid, y_valid),  # real-time validation
    verbose=1
)

# --- 5. RESULTS ANALYSIS ---
# Final evaluation on the test set (never seen data)
mse_test, mae_test = model_reg.evaluate(X_test, y_test)
print(f"\nMean Absolute Error on Test Set: {mae_test:.2f} (in hundreds of thousands of $)")
# Out:
# Input shape: 59 features
# Epoch 1/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5812 - mae: 0.5258 - val_loss: 1.6288 - val_mae: 0.5231
# Epoch 2/50
# 363/363 [==============================] - 0s 875us/step - loss: 0.3817 - mae: 0.4391 - val_loss: 0.4710 - val_mae: 0.4400
# Epoch 3/50
# 363/363 [==============================] - 0s 912us/step - loss: 0.3525 - mae: 0.4203 - val_loss: 1.7790 - val_mae: 0.4294
# Epoch 4/50
# 363/363 [==============================] - 0s 892us/step - loss: 0.3636 - mae: 0.4174 - val_loss: 3.9736 - val_mae: 0.4961
# Epoch 5/50
# 363/363 [==============================] - 0s 920us/step - loss: 0.3444 - mae: 0.4117 - val_loss: 0.4463 - val_mae: 0.4070
# Epoch 6/50
# 363/363 [==============================] - 0s 903us/step - loss: 0.3471 - mae: 0.3969 - val_loss: 5.7958 - val_mae: 0.4571
# Epoch 7/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3258 - mae: 0.3995 - val_loss: 14.4149 - val_mae: 0.4755
# Epoch 8/50
# 363/363 [==============================] - 0s 913us/step - loss: 0.3697 - mae: 0.3920 - val_loss: 1.6349 - val_mae: 0.4287
# Epoch 9/50
# 363/363 [==============================] - 0s 924us/step - loss: 0.3182 - mae: 0.3897 - val_loss: 0.3927 - val_mae: 0.4051
# Epoch 10/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3027 - mae: 0.3846 - val_loss: 10.8012 - val_mae: 0.4576
# Epoch 11/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3613 - mae: 0.3810 - val_loss: 0.3225 - val_mae: 0.3875
# Epoch 12/50
# 363/363 [==============================] - 0s 948us/step - loss: 0.2887 - mae: 0.3756 - val_loss: 0.4565 - val_mae: 0.3899
# Epoch 13/50
# 363/363 [==============================] - 0s 979us/step - loss: 0.2789 - mae: 0.3682 - val_loss: 0.3098 - val_mae: 0.3719
# Epoch 14/50
# 363/363 [==============================] - 0s 901us/step - loss: 0.2766 - mae: 0.3672 - val_loss: 0.3294 - val_mae: 0.3766
# Epoch 15/50
# 363/363 [==============================] - 0s 892us/step - loss: 0.2712 - mae: 0.3637 - val_loss: 0.3585 - val_mae: 0.3988
# Epoch 16/50
# 363/363 [==============================] - 0s 947us/step - loss: 0.2754 - mae: 0.3659 - val_loss: 0.3300 - val_mae: 0.4074
# Epoch 17/50
# 363/363 [==============================] - 0s 917us/step - loss: 0.2647 - mae: 0.3579 - val_loss: 0.2820 - val_mae: 0.3601
# Epoch 18/50
# 363/363 [==============================] - 0s 933us/step - loss: 0.2590 - mae: 0.3539 - val_loss: 0.3074 - val_mae: 0.3773
# Epoch 19/50
# 363/363 [==============================] - 0s 924us/step - loss: 0.2584 - mae: 0.3544 - val_loss: 0.2994 - val_mae: 0.3793
# Epoch 20/50
# 363/363 [==============================] - 0s 930us/step - loss: 0.2521 - mae: 0.3502 - val_loss: 0.2813 - val_mae: 0.3603
# Epoch 21/50
# 363/363 [==============================] - 0s 915us/step - loss: 0.2477 - mae: 0.3464 - val_loss: 0.2977 - val_mae: 0.3727
# Epoch 22/50
# 363/363 [==============================] - 0s 951us/step - loss: 0.2454 - mae: 0.3441 - val_loss: 0.3103 - val_mae: 0.3667
# Epoch 23/50
# 363/363 [==============================] - 0s 934us/step - loss: 0.2503 - mae: 0.3477 - val_loss: 0.2862 - val_mae: 0.3576
# Epoch 24/50
# 363/363 [==============================] - 0s 903us/step - loss: 0.2419 - mae: 0.3426 - val_loss: 0.3487 - val_mae: 0.3675
# Epoch 25/50
# 363/363 [==============================] - 0s 887us/step - loss: 0.2495 - mae: 0.3462 - val_loss: 0.6068 - val_mae: 0.3683
# Epoch 26/50
# 363/363 [==============================] - 0s 930us/step - loss: 0.2399 - mae: 0.3417 - val_loss: 0.3561 - val_mae: 0.3707
# Epoch 27/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.2376 - mae: 0.3385 - val_loss: 0.4800 - val_mae: 0.3775
# Epoch 28/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.2336 - mae: 0.3349 - val_loss: 0.7791 - val_mae: 0.3794
# Epoch 29/50
# 363/363 [==============================] - 0s 958us/step - loss: 0.2261 - mae: 0.3330 - val_loss: 0.3099 - val_mae: 0.3561
# Epoch 30/50
# 363/363 [==============================] - 0s 882us/step - loss: 0.2315 - mae: 0.3351 - val_loss: 0.2962 - val_mae: 0.3598
# Epoch 31/50
# 363/363 [==============================] - 0s 878us/step - loss: 0.2217 - mae: 0.3291 - val_loss: 0.3265 - val_mae: 0.3594
# Epoch 32/50
# 363/363 [==============================] - 0s 884us/step - loss: 0.2206 - mae: 0.3270 - val_loss: 0.2917 - val_mae: 0.3619
# Epoch 33/50
# 363/363 [==============================] - 0s 906us/step - loss: 0.2158 - mae: 0.3248 - val_loss: 0.4149 - val_mae: 0.3755
# Epoch 34/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.2169 - mae: 0.3262 - val_loss: 0.3545 - val_mae: 0.3626
# Epoch 35/50
# 363/363 [==============================] - 0s 977us/step - loss: 0.2120 - mae: 0.3231 - val_loss: 0.4534 - val_mae: 0.3757
# Epoch 36/50
# 363/363 [==============================] - 0s 888us/step - loss: 0.2110 - mae: 0.3205 - val_loss: 0.7528 - val_mae: 0.3735
# Epoch 37/50
# 363/363 [==============================] - 0s 896us/step - loss: 0.2124 - mae: 0.3215 - val_loss: 0.3712 - val_mae: 0.3780
# Epoch 38/50
# 363/363 [==============================] - 0s 876us/step - loss: 0.2071 - mae: 0.3184 - val_loss: 0.3180 - val_mae: 0.3589
# Epoch 39/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.1988 - mae: 0.3114 - val_loss: 0.3462 - val_mae: 0.3653
# Epoch 40/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.2245 - mae: 0.3211 - val_loss: 0.9713 - val_mae: 0.3730
# Epoch 41/50
# 363/363 [==============================] - 0s 915us/step - loss: 0.2101 - mae: 0.3171 - val_loss: 5.2051 - val_mae: 0.4132
# Epoch 42/50
# 363/363 [==============================] - 0s 921us/step - loss: 0.2196 - mae: 0.3144 - val_loss: 0.5711 - val_mae: 0.3770
# Epoch 43/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.2007 - mae: 0.3130 - val_loss: 1.7931 - val_mae: 0.3889
# Epoch 44/50
# 363/363 [==============================] - 0s 891us/step - loss: 0.2040 - mae: 0.3094 - val_loss: 0.4603 - val_mae: 0.3794
# Epoch 45/50
# 363/363 [==============================] - 0s 875us/step - loss: 0.1947 - mae: 0.3096 - val_loss: 1.1872 - val_mae: 0.4019
# Epoch 46/50
# 363/363 [==============================] - 0s 907us/step - loss: 0.1864 - mae: 0.3026 - val_loss: 0.4834 - val_mae: 0.3664
# Epoch 47/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.1872 - mae: 0.3018 - val_loss: 0.2876 - val_mae: 0.3570
# Epoch 48/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.1852 - mae: 0.3026 - val_loss: 0.3186 - val_mae: 0.3721
# Epoch 49/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.1857 - mae: 0.3033 - val_loss: 0.3896 - val_mae: 0.3772
# Epoch 50/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.1834 - mae: 0.3020 - val_loss: 0.3730 - val_mae: 0.3602
# 162/162 [==============================] - 0s 462us/step - loss: 0.3115 - mae: 0.3684
#
# Mean Absolute Error on Test Set: 0.37 (in hundreds of thousands of $)

# %%
# Visualize the learning curve
df_graph = pd.DataFrame(history.history)
df_graph = df_graph.drop(columns=["val_loss"], errors="ignore")
df_graph.plot(figsize=(8, 5))
plt.grid(True)
plt.title("Training Curves (Is loss decreasing, and is val_loss following?)")
plt.show()

# %% [markdown]
# - Versione base: Errore Medio Assoluto sul Test Set: 0.39
# - Rimozione outliers 0.7, drop ['AveRooms', 'AveBedrms', 'AveOccup', 'MedInc']: Errore Medio Assoluto sul Test Set: 0.49
# - Rimozione outliers 0.7, drop ['AveRooms', 'AveBedrms', 'AveOccup', 'MedInc'], con features combinate, neuroni 32, 16: Errore Medio Assoluto sul Test Set: 0.40
# - Rimozione outliers 0.7, drop ['AveRooms', 'AveBedrms', 'AveOccup', 'MedInc'], con features combinate, neuroni 128, 128, 64: Errore Medio Assoluto sul Test Set: 0.37
# - Rimozione outliers 0.7, drop ['AveRooms', 'AveBedrms', 'AveOccup', 'MedInc'], con features combinate, neuroni 128, 64: Errore Medio Assoluto sul Test Set: 0.39
# - Rimozione outliers 0.7, drop ['AveRooms', 'AveBedrms', 'AveOccup', 'MedInc'], con features combinate, neuroni 128, 128, 64, batch size 64: Errore Medio Assoluto sul Test Set: 0.38
# - Rimozione outliers 0.7, drop ['AveRooms', 'AveBedrms', 'AveOccup', 'MedInc'], con features combinate, neuroni 128, 128, 64, epoche 50: Errore Medio Assoluto sul Test Set: 0.37 (un pò di overfitting con mae che migliora e val mae che rimane un pò stabile)
